# %%
import pandas as pd

# %%
album=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\album.csv')

# %%
album
# Out:
#      album_id                                              title  artist_id
# 0         156                                And Justice For All         50
# 1         208                               Black Light Syndrome        136
# 2         257  20th Century Masters - The Millennium Collecti...        179
# 3         296                      A Copland Celebration, Vol. I        230
# 4          94                         A Matter of Life and Death         90
# ..        ...                                                ...        ...
# 342       239                                                War        150
# 343         8                                     Warner 25 Anos          6
# 344       334                       Weill: The Seven Deadly Sins        264
# 345       267                                             Worlds        202
# 346       240                                            Zooropa        150
#
# [347 rows x 3 columns]

# %%
album2=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\album2.csv')

# %%
album2
# Out:
#      album_id                                              title  artist_id
# 0           1              For Those About To Rock We Salute You          1
# 1           2                                  Balls to the Wall          2
# 2           3                                  Restless and Wild          2
# 3           4                                  Let There Be Rock          1
# 4           5                                           Big Ones          3
# ..        ...                                                ...        ...
# 342       343                              RespighiPines of Rome        226
# 343       344  Schubert The Late String Quartets & String Qui...        272
# 344       345                                  Monteverdi LOrfeo        273
# 345       346                               Mozart Chamber Music        274
# 346       347                                      Koyaanisqatsi        275
#
# [347 rows x 3 columns]

# %%
artist=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\artist.csv')

# %%
artist
# Out:
#      artist_id                                               name
# 0            1                                              AC/DC
# 1            2                                             Accept
# 2            3                                          Aerosmith
# 3            4                                  Alanis Morissette
# 4            5                                    Alice In Chains
# ..         ...                                                ...
# 270        271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp
# 271        272                             Emerson String Quartet
# 272        273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 273        274                                      Nash Ensemble
# 274        275                              Philip Glass Ensemble
#
# [275 rows x 2 columns]

# %%
customer=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\customer.csv')

# %%
customer
# Out:
#     customer_id first_name     last_name  \
# 0             1       Luís     Gonçalves
# 1             2     Leonie        Köhler
# 2             3   François      Tremblay
# 3             4      Bjørn        Hansen
# 4             5  František   Wichterlová
# 5             6     Helena          Holý
# 6             7     Astrid        Gruber
# 7             8       Daan       Peeters
# 8             9       Kara       Nielsen
# 9            10    Eduardo       Martins
# 10           11  Alexandre         Rocha
# 11           12    Roberto       Almeida
# 12           13   Fernanda         Ramos
# 13           14       Mark       Philips
# 14           15   Jennifer      Peterson
# 15           16      Frank        Harris
# 16           17       Jack         Smith
# 17           18   Michelle        Brooks
# 18           19        Tim         Goyer
# 19           20        Dan        Miller
# 20           21      Kathy         Chase
# 21           22    Heather       Leacock
# ...

# %%
employee=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\employee.csv')

# %%
employee
# Out:
#    employee_id last_name first_name                   title  reports_to  \
# 0            1     Adams     Andrew         General Manager         9.0
# 1            2   Edwards      Nancy           Sales Manager         1.0
# 2            3   Peacock       Jane     Sales Support Agent         2.0
# 3            4      Park   Margaret     Sales Support Agent         2.0
# 4            5   Johnson      Steve     Sales Support Agent         2.0
# 5            6  Mitchell    Michael              IT Manager         1.0
# 6            7      King     Robert                IT Staff         6.0
# 7            8  Callahan      Laura                IT Staff         6.0
# 8            9     Madan      Mohan  Senior General Manager         NaN
#
#   levels         birthdate         hire_date                      address  \
# 0     L6  18-02-1962 00:00  14-08-2016 00:00          11120 Jasper Ave NW
# 1     L4  08-12-1958 00:00  01-05-2016 00:00                 825 8 Ave SW
# ...

# %%
genre=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\genre.csv')

# %%
genre
# Out:
#     genre_id                name
# 0          1                Rock
# 1          2                Jazz
# 2          3               Metal
# 3          4  Alternative & Punk
# 4          5       Rock And Roll
# 5          6               Blues
# 6          7               Latin
# 7          8              Reggae
# 8          9                 Pop
# 9         10          Soundtrack
# 10        11          Bossa Nova
# 11        12      Easy Listening
# 12        13         Heavy Metal
# 13        14            R&B/Soul
# 14        15   Electronica/Dance
# 15        16               World
# 16        17         Hip Hop/Rap
# 17        18     Science Fiction
# 18        19            TV Shows
# 19        20    Sci Fi & Fantasy
# 20        21               Drama
# 21        22              Comedy
# 22        23         Alternative
# 23        24           Classical
# 24        25               Opera

# %%
invoice=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\invoice.csv')

# %%
invoice
# Out:
#      invoice_id  customer_id         invoice_date       billing_address  \
# 0             1           18  2017-01-03 00:00:00          627 Broadway
# 1             2           30  2017-01-03 00:00:00      230 Elgin Street
# 2             3           40  2017-01-05 00:00:00        8, Rue Hanovre
# 3             4           18  2017-01-06 00:00:00          627 Broadway
# 4             5           27  2017-01-07 00:00:00       1033 N Park Ave
# ..          ...          ...                  ...                   ...
# 609         610           55  2020-12-21 00:00:00     421 Bourke Street
# 610         611           52  2020-12-27 00:00:00     202 Hoxton Street
# 611         612           33  2020-12-27 00:00:00        5112 48 Street
# 612         613           20  2020-12-29 00:00:00  541 Del Medio Avenue
# 613         614           53  2020-12-30 00:00:00          113 Lupus St
#
#       billing_city billing_state billing_country billing_postal_code  total
# ...

# %%
invoice_line=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\invoice_line.csv')

# %%
invoice_line
# Out:
#       invoice_line_id  invoice_id  track_id  unit_price  quantity
# 0                   1           1      1158        0.99         1
# 1                   2           1      1159        0.99         1
# 2                   3           1      1160        0.99         1
# 3                   4           1      1161        0.99         1
# 4                   5           1      1162        0.99         1
# ...               ...         ...       ...         ...       ...
# 4752             4753         614      2659        0.99         1
# 4753             4754         614      2660        0.99         1
# 4754             4755         614      2661        0.99         1
# 4755             4756         614      2662        0.99         1
# 4756             4757         614      2663        0.99         1
#
# [4757 rows x 5 columns]

# %%
media_type=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\media_type.csv')

# %%
media_type
# Out:
#    media_type_id                         name
# 0              1              MPEG audio file
# 1              2     Protected AAC audio file
# 2              3  Protected MPEG-4 video file
# 3              4     Purchased AAC audio file
# 4              5               AAC audio file

# %%
playlist=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\playlist.csv')

# %%
playlist
# Out:
#     playlist_id                        name
# 0             1                       Music
# 1             2                      Movies
# 2             3                    TV Shows
# 3             4                  Audiobooks
# 4             5                  90’s Music
# 5             6                  Audiobooks
# 6             7                      Movies
# 7             8                       Music
# 8             9                Music Videos
# 9            10                    TV Shows
# 10           11             Brazilian Music
# 11           12                   Classical
# 12           13   Classical 101 - Deep Cuts
# 13           14  Classical 101 - Next Steps
# 14           15  Classical 101 - The Basics
# 15           16                      Grunge
# 16           17         Heavy Metal Classic
# 17           18                 On-The-Go 1

# %%
playlist_track=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\playlist_track.csv')

# %%
playlist_track
# Out:
#       playlist_id  track_id
# 0               1      3402
# 1               1      3389
# 2               1      3390
# 3               1      3391
# 4               1      3392
# ...           ...       ...
# 8710           17      2094
# 8711           17      2095
# 8712           17      2096
# 8713           17      3290
# 8714           18       597
#
# [8715 rows x 2 columns]

# %%
track=pd.read_csv(r'C:\Users\DELL\OneDrive\Desktop\music store data\track.csv')

# %%
track
# Out:
#       track_id                                               name  album_id  \
# 0            1            For Those About To Rock (We Salute You)         1
# 1            2                                  Balls to the Wall         2
# 2            3                                    Fast As a Shark         3
# 3            4                                  Restless and Wild         3
# 4            5                               Princess of the Dawn         3
# ...        ...                                                ...       ...
# 3498      3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       343
# 3499      3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       344
# 3500      3501               L'orfeo, Act 3, Sinfonia (Orchestra)       345
# 3501      3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       346
# 3502      3503                                      Koyaanisqatsi       347
#
#       media_type_id  genre_id  \
# ...

# %%
from IPython.display import Image

# Replace 'path/to/your/image.png' with the actual path to your PNG image file
Image(filename=r'C:\Users\DELL\OneDrive\Desktop\music store data\schema_diagram.png')

# %%
import sqlite3

# %%
connect=sqlite3.connect('music_database.db')  #to create sqlite3 database as 'music_database' using 'connect' function.

# %%
cursor=connect.cursor() #we have made a cursor object to execute sql through 'connect'function.

# %%
album.to_sql('album', connect, index=False, if_exists='replace')
# Out:
# 347

# %%
cursor.execute('select * from album') #to execute the query in the database

# %%
cursor.fetchall()   #to display the result of last query.
# Out:
# [(156, 'And Justice For All', 50),
#  (208, 'Black Light Syndrome', 136),
#  (257,
#   '20th Century Masters - The Millennium Collection: The Best of Scorpions',
#   179),
#  (296, 'A Copland Celebration, Vol. I', 230),
#  (94, 'A Matter of Life and Death', 90),
#  (95, 'A Real Dead One', 90),
#  (96, 'A Real Live One', 90),
#  (285, 'A Soprano Inspired', 219),
#  (139, 'A TempestadeTempestade Ou O Livro Dos Dias', 99),
#  (224, 'Acastico', 146),
#  (167, 'Acastico MTV', 113),
#  (26, 'Acastico MTV live', 19),
#  (160, 'Ace Of Spades', 106),
#  (232, 'Achtung Baby', 150),
#  (307, 'Adams, John: The Chairman Dances', 242),
#  (272, 'Adorate Deum: Gregorian Chant from the Proper of the Mass', 206),
#  (24, 'Afrociberdelia', 18),
#  (74, 'Album Of The Year', 82),
#  (14, 'Alcohol Fueled Brewtality Live! [Disc 1]', 11),
#  (15, 'Alcohol Fueled Brewtality Live! [Disc 2]', 11),
#  (233, "All That You Can't Leave Behind", 150),
#  (273, 'Allegri: Miserere', 207),
# ...

# %%
album
# Out:
#      album_id                                              title  artist_id
# 0         156                                And Justice For All         50
# 1         208                               Black Light Syndrome        136
# 2         257  20th Century Masters - The Millennium Collecti...        179
# 3         296                      A Copland Celebration, Vol. I        230
# 4          94                         A Matter of Life and Death         90
# ..        ...                                                ...        ...
# 342       239                                                War        150
# 343         8                                     Warner 25 Anos          6
# 344       334                       Weill: The Seven Deadly Sins        264
# 345       267                                             Worlds        202
# 346       240                                            Zooropa        150
#
# [347 rows x 3 columns]

# %%
disco_lst=['album2','artist','customer','employee','genre','invoice','invoice_line','media_type','playlist','playlist_track','track']

# %%
#for i in disco_lst:
 #   df=globals()[i]
  #  df.to_sql(i,connect,index=False)

# %%
cursor.execute('select * from invoice')

# %%
cursor.fetchall()
# Out:
# [(1,
#   18,
#   '2017-01-03 00:00:00',
#   '627 Broadway',
#   'New York',
#   'NY',
#   'USA',
#   '10012-2612',
#   15.84),
#  (2,
#   30,
#   '2017-01-03 00:00:00',
#   '230 Elgin Street',
#   'Ottawa',
#   'ON',
#   'Canada',
#   'K2P 1L7',
#   9.9),
#  (3,
#   40,
#   '2017-01-05 00:00:00',
#   '8, Rue Hanovre',
#   'Paris',
#   None,
#   'France',
#   '75002',
#   1.98),
#  (4,
#   18,
#   '2017-01-06 00:00:00',
#   '627 Broadway',
#   'New York',
#   'NY',
#   'USA',
#   '10012-2612',
#   7.92),
#  (5,
#   27,
#   '2017-01-07 00:00:00',
#   '1033 N Park Ave',
#   'Tucson',
#   'AZ',
#   'USA',
#   '85719',
#   16.83),
#  (6,
#   31,
#   '2017-01-10 00:00:00',
#   '194A Chain Lake Drive',
#   'Halifax',
#   'NS',
#   'Canada',
#   'B3S 1C5',
#   1.98),
#  (7,
#   49,
#   '2017-01-12 00:00:00',
#   'Ordynacka 10',
#   'Warsaw',
#   None,
#   'Poland',
#   '00-358',
#   10.89),
#  (8,
#   59,
#   '2017-01-13 00:00:00',
#   '3,Raj Bhavan Road',
#   'Bangalore',
#   None,
# ...

# %%
cursor.execute('select first_name,last_name,title from employee order by levels desc limit 1')
cursor.fetchall()
# Out:
# [('Mohan', 'Madan', 'Senior General Manager')]

# %%
cursor.execute('SELECT COUNT(*) AS c, billing_country FROM invoice GROUP BY billing_country ORDER BY c DESC limit 5')
cursor.fetchall()
# Out:
# [(131, 'USA'), (76, 'Canada'), (61, 'Brazil'), (50, 'France'), (41, 'Germany')]

# %%
cursor.execute('select total from invoice order by total desc limit 3')
cursor.fetchall()
# Out:
# [(23.76,), (19.8,), (19.8,)]

# %%
cursor.execute('select c.city,sum(i.total) from customer as c join invoice as i on c.customer_id=i.customer_id group by city order by total desc limit 1')
cursor.fetchall()
# Out:
# [('New York', 79.2)]

# %%
cursor.execute('select first_name,last_name, sum(total) from customer join invoice on customer.customer_id=invoice.customer_id group by customer.customer_id order by total desc limit 1 ')
cursor.fetchall()
# Out:
# [('Michelle', 'Brooks', 79.2)]

# %%
cursor.execute('SELECT billing_city,SUM(total) AS InvoiceTotal FROM invoice GROUP BY billing_city ORDER BY InvoiceTotal DESC LIMIT 1')
cursor.fetchall()
# Out:
# [('Prague', 273.24000000000007)]

# %%
cursor.execute('SELECT customer.customer_id, first_name, last_name, SUM(total) AS total_spending FROM customer JOIN invoice ON customer.customer_id = invoice.customer_id GROUP BY customer.customer_id ORDER BY total_spending DESC LIMIT 1')
cursor.fetchall()
# Out:
# [(5, 'František', 'Wichterlová', 144.54000000000002)]

# %%
cursor.execute('select * from genre')
cursor.fetchall()
# Out:
# [(1, 'Rock'),
#  (2, 'Jazz'),
#  (3, 'Metal'),
#  (4, 'Alternative & Punk'),
#  (5, 'Rock And Roll'),
#  (6, 'Blues'),
#  (7, 'Latin'),
#  (8, 'Reggae'),
#  (9, 'Pop'),
#  (10, 'Soundtrack'),
#  (11, 'Bossa Nova'),
#  (12, 'Easy Listening'),
#  (13, 'Heavy Metal'),
#  (14, 'R&B/Soul'),
#  (15, 'Electronica/Dance'),
#  (16, 'World'),
#  (17, 'Hip Hop/Rap'),
#  (18, 'Science Fiction'),
#  (19, 'TV Shows'),
#  (20, 'Sci Fi & Fantasy'),
#  (21, 'Drama'),
#  (22, 'Comedy'),
#  (23, 'Alternative'),
#  (24, 'Classical'),
#  (25, 'Opera')]

# %%
cursor.execute('select first_name,last_name,email,count(distinct customer.customer_id) from customer join invoice on customer.customer_id = invoice.customer_id join invoice_line on invoice.invoice_id = invoice_line.invoice_id join track on invoice_line.track_id=track.track_id where genre_id in (select genre_id from genre where name like "Rock%" ) order by email ')
cursor.fetchall()
# Out:
# [('Phil', 'Hughes', 'phil.hughes@gmail.com', 59)]

# %%
cursor.execute('select * from artist')
cursor.fetchall()
# Out:
# [(1, 'AC/DC'),
#  (2, 'Accept'),
#  (3, 'Aerosmith'),
#  (4, 'Alanis Morissette'),
#  (5, 'Alice In Chains'),
#  (6, 'Antônio Carlos Jobim'),
#  (7, 'Apocalyptica'),
#  (8, 'Audioslave'),
#  (9, 'BackBeat'),
#  (10, 'Billy Cobham'),
#  (11, 'Black Label Society'),
#  (12, 'Black Sabbath'),
#  (13, 'Body Count'),
#  (14, 'Bruce Dickinson'),
#  (15, 'Buddy Guy'),
#  (16, 'Caetano Veloso'),
#  (17, 'Chico Buarque'),
#  (18, 'Chico Science & Nação Zumbi'),
#  (19, 'Cidade Negra'),
#  (20, 'Cláudio Zoli'),
#  (21, 'Various Artists'),
#  (22, 'Led Zeppelin'),
#  (23, 'Frank Zappa & Captain Beefheart'),
#  (24, 'Marcos Valle'),
#  (25, 'Milton Nascimento & Bebeto'),
#  (26, 'Azymuth'),
#  (27, 'Gilberto Gil'),
#  (28, 'João Gilberto'),
#  (29, 'Bebel Gilberto'),
#  (30, 'Jorge Vercilo'),
#  (31, 'Baby Consuelo'),
#  (32, 'Ney Matogrosso'),
#  (33, 'Luiz Melodia'),
#  (34, 'Nando Reis'),
#  (35, 'Pedro Luís & A Parede'),
#  (36, 'O Rappa'),
#  (37, 'Ed Motta'),
#  (38, 'Banda Black Rio'),
# ...
